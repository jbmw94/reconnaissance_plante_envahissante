# %%
import os

# %%
import pymongo 
import math

# define the client, the database, and the collection
# the database and the collection are created at first insert 
# if needed
client = pymongo.MongoClient('localhost',27017)
mydb = client["projet_final"]
sinfun = mydb["plante_collection"]

# %%
import shutil
import os


path= "C:/Users/utilisateur/Desktop/projet chef-d'oeuvre/image projet"
listfold = os.listdir(path)
# Out:
# C:/Users/utilisateur/Desktop/projet chef-d'oeuvre/image projet/Caulerpa cylindracea Sonder, 1845\Caulerpa cylindracea Sonder, 1845_original_Caulerpa cylindracea Sonder, 1845 (1).png_0ed3ae97-099a-4aa7-9564-40b27305bd18.png
# C:/Users/utilisateur/Desktop/projet chef-d'oeuvre/image projet/Caulerpa cylindracea Sonder, 1845\Caulerpa cylindracea Sonder, 1845_original_Caulerpa cylindracea Sonder, 1845 (1).png_24fbd54b-b679-4b89-9679-a24c6466125e.png
# C:/Users/utilisateur/Desktop/projet chef-d'oeuvre/image projet/Caulerpa cylindracea Sonder, 1845\Caulerpa cylindracea Sonder, 1845_original_Caulerpa cylindracea Sonder, 1845 (1).png_2f9ae345-30b1-4ed2-ad3b-785c15dd5ccc.png
# C:/Users/utilisateur/Desktop/projet chef-d'oeuvre/image projet/Caulerpa cylindracea Sonder, 1845\Caulerpa cylindracea Sonder, 1845_original_Caulerpa cylindracea Sonder, 1845 (1).png_74edd99f-4749-4244-a6d6-d86b63cfa8e1.png
# ...

# %%
#avec os tu fait un listfold a partir du path
for i in range(len(listfold)) : 
    

    listfile = os.listdir(path+'/'+listfold[i])
    for img in listfile : 


        print('insert')
        data = []
        data.append ({"dossier":listfold[i], "image":img})    
        sinfun.insert_many(data)
        print('done')
# Out:
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# insert
# done
# ...

# %%
import pandas as pd
cursor = sinfun.find()
entries = list(cursor)
entries[:5]
# Out:
# [{'_id': ObjectId('60df4625a4e1c3aceee36d18'),
#   'dossier': 'Acacia dealbata Link, 1822',
#   'image': 'Acacia dealbata Link, 1822 (1).png'},
#  {'_id': ObjectId('60df4625a4e1c3aceee36d19'),
#   'dossier': 'Acacia dealbata Link, 1822',
#   'image': 'Acacia dealbata Link, 1822 (1).png'},
#  {'_id': ObjectId('60df4625a4e1c3aceee36d1a'),
#   'dossier': 'Acacia dealbata Link, 1822',
#   'image': 'Acacia dealbata Link, 1822 (1).png'},
#  {'_id': ObjectId('60df4625a4e1c3aceee36d1b'),
#   'dossier': 'Acacia dealbata Link, 1822',
#   'image': 'Acacia dealbata Link, 1822 (1).png'},
#  {'_id': ObjectId('60df4625a4e1c3aceee36d1c'),
#   'dossier': 'Acacia dealbata Link, 1822',
#   'image': 'Acacia dealbata Link, 1822 (1).png'}]

# %%
cursor = sinfun.find()
entries = list(cursor)
entries[:5]
# Out:
# [{'_id': ObjectId('60e2d0d66763540468d22aec'),
#   'Nom de référence': 'Acacia dealbata Link, 1822',
#   'image': "C:/Users/utilisateur/Desktop/projet chef-d'oeuvre/image projet/Acacia dealbata Link, 1822/Acacia dealbata Link, 1822 (1).png",
#   'Nom vernaculaire': 'Mimosa argenté, Mimosa des fleuristes, Mimosa de Bormes',
#   'Statut*': 'J',
#   'Règne': 'Plantae (Plantes)',
#   'Classe': 'Equisetopsida (Plantes terrestres, Embryophytes, Cormophytes)',
#   'Ordre': 'Fabales',
#   'Famille': 'Fabaceae',
#   'CD_REF': '79691',
#   'CD_NOM': '79691'},
#  {'_id': ObjectId('60e2d0d66763540468d22aed'),
#   'Nom de référence': 'Acacia dealbata Link, 1822',
#   'image': "C:/Users/utilisateur/Desktop/projet chef-d'oeuvre/image projet/Acacia dealbata Link, 1822/Acacia dealbata Link, 1822 (10).png",
#   'Nom vernaculaire': 'Mimosa argenté, Mimosa des fleuristes, Mimosa de Bormes',
#   'Statut*': 'J',
#   'Règne': 'Plantae (Plantes)',
# ...

# %%
cursor.close()
