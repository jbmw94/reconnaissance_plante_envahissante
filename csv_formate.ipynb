# %%
import pandas as pd

df = pd.read_csv("path_image_plante_envahissante.csv")
df2 = pd.read_csv("INPN - Espèces introduites envahissantes (invasive)rechercherrechercher_202161(1).csv", sep = ';', index_col=0)

# %%
df = df.rename(columns = {'dossier': 'Nom de référence'})

# %%
plante_collection = pd.merge(df, df2)

# %%
plante_collection.to_csv("plante_collection.csv", index = False)

# %%
plante_collection["Nom de référence"]=mod_ref

# %%
plante_collection
# Out:
#                                         Nom de référence  \
# 0                             Acacia dealbata Link, 1822
# 1                             Acacia dealbata Link, 1822
# 2                             Acacia dealbata Link, 1822
# 3                             Acacia dealbata Link, 1822
# 4                             Acacia dealbata Link, 1822
# ...                                                  ...
# 12993  Womersleyella setacea (Hollenb.) R.E. Norris, ...
# 12994  Womersleyella setacea (Hollenb.) R.E. Norris, ...
# 12995  Womersleyella setacea (Hollenb.) R.E. Norris, ...
# 12996  Womersleyella setacea (Hollenb.) R.E. Norris, ...
# 12997  Womersleyella setacea (Hollenb.) R.E. Norris, ...
#
#                                                    image  \
# 0      C:/Users/utilisateur/Desktop/projet chef-d'oeu...
# 1      C:/Users/utilisateur/Desktop/projet chef-d'oeu...
# 2      C:/Users/utilisateur/Desktop/projet chef-d'oeu...
# ...

# %%
mod_ref = plante_collection["Nom de référence"]
nb = 0
i = 0 
while i<len(mod_ref):
    nom = mod_ref[i]
    mod_ref[i] = nom.replace(" x ", " x")
    if mod_ref[i] == "Spiraea x billardii Hérincq, 1857" or mod_ref[i] == "Spiraea xbillardii Hérincq, 1857" :
        nb = i
    i+=1
        #nom.replace(" x ", " x")
print(mod_ref[nb], " ", nb)
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Spiraea xbillardii Hérincq, 1857   12664

# %%
for i in mod_ref :

# %%
for i in mod_ref : 
    if i=="Spiraea x billardii Hérincq, 1857" : 
        print('pas transformé')
    elif i=="Spiraea xbillardii Hérincq, 1857": 
        print('transformé')
# Out:
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# transformé
# ...
